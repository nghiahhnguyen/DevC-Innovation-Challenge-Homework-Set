# %% [markdown]
# # Team 2 - Google Play Store
#
# ![](https://www.brandnol.com/wp-content/uploads/2019/04/Google-Play-Store-Search.jpg)
#
# _For more information about the dataset, read [here](https://www.kaggle.com/lava18/google-play-store-apps)._
#
# ## Your tasks
# - Name your team!
# - Read the source and do some quick research to understand more about the dataset and its topic
# - Clean the data
# - Perform Exploratory Data Analysis on the dataset
# - Analyze the data more deeply and extract insights
# - Visualize your analysis on Google Data Studio
# - Present your works in front of the class and guests next Monday
#
# ## Submission Guide
# - Create a Github repository for your project
# - Upload the dataset (.csv file) and the Jupyter Notebook to your Github repository. In the Jupyter Notebook, **include the link to your Google Data Studio report**.
# - Submit your works through this [Google Form](https://forms.gle/oxtXpGfS8JapVj3V8).
#
# ## Tips for Data Cleaning, Manipulation & Visualization
# - Here are some of our tips for Data Cleaning, Manipulation & Visualization. [Click here](https://hackmd.io/cBNV7E6TT2WMliQC-GTw1A)
#
# _____________________________
#
# ## Some Hints for This Dataset:
# - There are lots of null values. How should we handle them?
# - Column `Installs` and `Size` have some strange values. Can you identify them?
# - Values in `Size` column are currently in different format: `M`, `k`. And how about the value `Varies with device`?
# - `Price` column is not in the right data type
# - And more...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
link = '/content/drive/My Drive/Colab Notebooks/Week04/google-play-store.csv'
apps = pd.read_csv(link)
print('The number of apps is', apps.size)
apps.head()
# Out:
# The number of apps is 140933
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
apps['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 4. , 4.8, 4.9, 3.6,
#        3.7, 3.2, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8, 2.7,
#        1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %% [markdown]
# # Preprocessing the data

# %%
# Show columns with NaN
apps[apps.isnull().any(axis=1)]
# Out:
#                                    App  ... Android Ver
# 15     Learn To Draw Kawaii Characters  ...  4.2 and up
# 23              Mcqueen Coloring pages  ...  4.1 and up
# 113          Wrinkles and rejuvenation  ...  3.0 and up
# 123             Manicure - nail design  ...  4.1 and up
# 126       Skin Care and Natural Beauty  ...  4.1 and up
# ...                                ...  ...         ...
# 10824                        Cardio-FR  ...  4.4 and up
# 10825               Naruto & Boruto FR  ...  4.0 and up
# 10831         payermonstationnement.fr  ...  4.0 and up
# 10835                         FR Forms  ...  4.0 and up
# 10838           Parkinson Exercices FR  ...  2.2 and up
#
# [1481 rows x 13 columns]

# %%
# Drop all rows with a NaN value because the number of rows dropped is negligible (only about 1%)
apps.dropna(inplace=True)
apps.size
# Out:
# 121680

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
# App               9360 non-null object
# Category          9360 non-null object
# Rating            9360 non-null float64
# Reviews           9360 non-null object
# Size              9360 non-null object
# Installs          9360 non-null object
# Type              9360 non-null object
# Price             9360 non-null object
# Content Rating    9360 non-null object
# Genres            9360 non-null object
# Last Updated      9360 non-null object
# Current Ver       9360 non-null object
# Android Ver       9360 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1023.8+ KB

# %%
apps.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
def preprocess_install(data):
    data = data.replace(',', '')
    if data[-1] == '+':
        return int(data[:-1])
    return int(data)
apps['Installs'] = apps['Installs'].apply(preprocess_install)

# %%
apps.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
# Change
apps['Rating'].astype('float32')
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10834    4.0
# 10836    4.5
# 10837    5.0
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 9360, dtype: float32

# %%
apps.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
# Distinct value for type
apps['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
def preprocess_size(data):
    factor_char_to_num = {
        'k': 1024,
        'M': int(1024**2),
        'G': int(1024**3)
    }
    factor_char = data[-1:]
    if data == 'Varies with device':
        ans = -1
    elif factor_char.isalpha():
        factor_num = factor_char_to_num[factor_char]
        value = float(data[:-1])
        ans = value * factor_num
    else:
        factor_num = 1
        value = int(data[:-1])
        ans = value
    return int(ans)

# %%
apps['Size'] = apps['Size'].apply(preprocess_size)
apps.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
apps['Price'] = apps['Price'].apply(lambda x: x if x[0] != '$' else x[1:])
apps.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
apps['Price'] = apps['Price'].astype('float64')

# %%
apps['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   7.99,   5.99,   2.99,   3.49,
#          1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,  24.99,
#         11.99,  79.99,  16.99,  14.99,  29.99,  12.99,   2.49,  10.99,
#          1.5 ,  19.99,  15.99,  33.99,  39.99,   3.95,   4.49,   1.7 ,
#          8.99,   1.49,   3.88, 399.99,  17.99, 400.  ,   3.02,   1.76,
#          4.84,   4.77,   1.61,   2.5 ,   1.59,   6.49,   1.29, 299.99,
#        379.99,  37.99,  18.99, 389.99,   8.49,   1.75,  14.  ,   2.  ,
#          3.08,   2.59,  19.4 ,   3.9 ,   4.59,  15.46,   3.04,  13.99,
#          4.29,   3.28,   4.6 ,   1.  ,   2.95,   2.9 ,   1.97,   2.56,
#          1.2 ])

# %%
genres = dict()

for index, row in apps.iterrows():
    genre_list_str = row[9]
    genre_list = list(genre_list_str.split(';'))
    for genre in genre_list:
        if genre not in genres:
            genres[genre] = 1
        else:
            genres[genre] += 1

genres_names = []
genres_counts = []
for k, v in genres.items():
    genres_names.append(k)
    genres_counts.append(v)
genres_df = pd.DataFrame(list(zip(genres_names, genres_counts)), columns=['Genre', 'Frequency'])
genres_df
# Out:
#                       Genre  Frequency
# 0              Art & Design         64
# 1              Pretend Play         89
# 2                Creativity         36
# 3           Auto & Vehicles         73
# 4                    Beauty         42
# 5         Books & Reference        180
# 6                  Business        303
# 7                    Comics         58
# 8             Communication        329
# 9                    Dating        195
# 10                Education        670
# 11            Music & Video         47
# 12       Action & Adventure        135
# 13              Brain Games         69
# 14            Entertainment        577
# 15                   Events         45
# 16                  Finance        323
# 17             Food & Drink        109
# 18         Health & Fitness        299
# 19             House & Home         76
# 20         Libraries & Demo         64
# 21                Lifestyle        315
# 22                Adventure         89
# 23                   Arcade        223
# 24                   Casual        262
# 25                     Card         48
# 26                   Action        375
# 27                 Strategy        107
# 28                   Puzzle        147
# 29                   Sports        337
# 30                    Music         24
# 31                     Word         28
# 32                   Racing        114
# 33               Simulation        212
# 34                    Board         60
# 35                   Trivia         28
# 36             Role Playing        119
# 37              Educational        103
# 38            Music & Audio          1
# 39  Video Players & Editors        163
# 40                  Medical        350
# 41                   Social        259
# 42                 Shopping        238
# 43              Photography        317
# 44           Travel & Local        226
# 45                    Tools        733
# 46          Personalization        312
# 47             Productivity        351
# 48                Parenting         50
# 49                  Weather         75
# 50         News & Magazines        233
# 51        Maps & Navigation        124
# 52                   Casino         37

# %%
apps['Reviews'] = apps['Reviews'].astype('int64')

# %%
# remove duplicated version of apps (they are basically the same app with just small derivation in the number of reviews)
apps.drop_duplicates(['App', 'Current Ver'], inplace=True)

# %%
apps.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
apps.to_csv('preprecossesed_apps.csv', index=False)
genres_df.to_csv('genres.csv', index=False)

# %% [markdown]
# # Analyze the data

# %%
# Top 10 most reviewed apps
apps.sort_values('Reviews', ascending=False).head(10)
# Out:
#                                                     App  ...         Android Ver
# 2544                                           Facebook  ...  Varies with device
# 336                                  WhatsApp Messenger  ...  Varies with device
# 2545                                          Instagram  ...  Varies with device
# 335            Messenger – Text and Video Chat for Free  ...  Varies with device
# 1670                                     Clash of Clans  ...          4.1 and up
# 4005            Clean Master- Space Cleaner & Antivirus  ...  Varies with device
# 1654                                     Subway Surfers  ...          4.1 and up
# 3665                                            YouTube  ...  Varies with device
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...  ...  Varies with device
# 1660                                       Clash Royale  ...          4.1 and up
#
# [10 rows x 13 columns]

# %%
apps['Reviews'].describe()
# Out:
# count    8.200000e+03
# mean     2.562877e+05
# std      1.986809e+06
# min      1.000000e+00
# 25%      1.267500e+02
# 50%      3.027000e+03
# 75%      4.406425e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
# Among apps with more than 3000 revies, what are the 10 highest rated apps?
apps_rating = apps.sort_values('Reviews', ascending=False)
apps_rating[apps_rating['Reviews'] > 3000].sort_values('Rating').tail(10)
# Out:
#                                                      App  ...         Android Ver
# 10016                                    Eddsworld Amino  ...        4.0.3 and up
# 1307   StrongLifts 5x5 Workout Gym Log & Personal Tra...  ...  Varies with device
# 64                 DMV Permit Practice Test 2018 Edition  ...          4.2 and up
# 6052                      Be My Eyes - Helping the blind  ...          4.4 and up
# 1833                                  The Room: Old Sins  ...          4.4 and up
# 99                        ipsy: Makeup, Beauty, and Tips  ...          4.1 and up
# 61                        CDL Practice Test 2018 Edition  ...          4.2 and up
# 2344                                      Period Tracker  ...          4.1 and up
# 1260                   Six Pack in 30 Days - Abs Workout  ...          4.2 and up
# 55     Tickets SDA 2018 and Exam from the State Traff...  ...          4.0 and up
#
# [10 rows x 13 columns]

# %%
apps_rating = apps.sort_values('Reviews', ascending=False)
apps_rating[apps_rating['Reviews'] > 4e4].sort_values('Rating').tail(10)
# Out:
#                                                     App  ...         Android Ver
# 4799                        PewDiePie's Tuber Simulator  ...          4.1 and up
# 2344                                     Period Tracker  ...          4.1 and up
# 1307  StrongLifts 5x5 Workout Gym Log & Personal Tra...  ...  Varies with device
# 79                              Tickets + PDA 2018 Exam  ...          4.1 and up
# 3933  Hungry Hearts Diner: A Tale of Star-Crossed Souls  ...          4.0 and up
# 7000  PixPanda - Color by Number Pixel Art Coloring ...  ...        4.0.3 and up
# 99                       ipsy: Makeup, Beauty, and Tips  ...          4.1 and up
# 712      Learn Japanese, Korean, Chinese Offline & Free  ...          4.2 and up
# 9625                                         JW Library  ...  Varies with device
# 1260                  Six Pack in 30 Days - Abs Workout  ...          4.2 and up
#
# [10 rows x 13 columns]

# %% [markdown]
# ## What is the most popular social network application by the number of reviews?

# %%
apps_rating = apps.sort_values('Reviews', ascending=False)
apps_rating[apps_rating['Category'] == 'SOCIAL'].head(15)
# Out:
#                                  App  ...         Android Ver
# 2544                        Facebook  ...  Varies with device
# 2545                       Instagram  ...  Varies with device
# 2550                        Snapchat  ...  Varies with device
# 2546                   Facebook Lite  ...  Varies with device
# 6373                              VK  ...  Varies with device
# 3945  Tik Tok - including musical.ly  ...          4.1 and up
# 2554                         Google+  ...  Varies with device
# 2552                       Pinterest  ...  Varies with device
# 2592    Tango - Live Video Broadcast  ...  Varies with device
# 2588  Badoo - Free Chat & Dating App  ...  Varies with device
# 2548                          Tumblr  ...  Varies with device
# 3951         BIGO LIVE - Live Stream  ...          4.0 and up
# 2622                            Path  ...  Varies with device
# 2593  MeetMe: Chat & Meet New People  ...          4.1 and up
# 2571    Amino: Communities and Chats  ...        4.0.3 and up
#
# [15 rows x 13 columns]

# %% [markdown]
# ## Which categories have the most applications in store?

# %%
apps['Category'].value_counts()[:10]
# Out:
# FAMILY             1612
# GAME                913
# TOOLS               719
# FINANCE             302
# LIFESTYLE           301
# PRODUCTIVITY        301
# PERSONALIZATION     296
# MEDICAL             291
# BUSINESS            263
# PHOTOGRAPHY         263
# Name: Category, dtype: int64

# %% [markdown]
# ## Which genres have the most app in the store?

# %%
genres_df.sort_values('Frequency', ascending=False).head(10).reset_index(drop=True)
# Out:
#            Genre  Frequency
# 0          Tools        733
# 1      Education        670
# 2  Entertainment        577
# 3         Action        375
# 4   Productivity        351
# 5        Medical        350
# 6         Sports        337
# 7  Communication        329
# 8        Finance        323
# 9    Photography        317

# %% [markdown]
# ## Is rating in Google Store inflated?

# %%
apps['Rating'].value_counts().sort_values(ascending=False).head(10)
# Out:
# 4.3    898
# 4.4    897
# 4.5    849
# 4.2    809
# 4.6    684
# 4.1    622
# 4.0    512
# 4.7    442
# 3.9    359
# 3.8    286
# Name: Rating, dtype: int64

# %%
import matplotlib.pyplot as plt

_ = pd.value_counts(apps['Rating']).plot(kind='bar')

# %%
apps['Content Rating'].value_counts()
# Out:
# Everyone           6622
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content Rating, dtype: int64

# %%
pd.value_counts(apps['Content Rating']).plot(kind='bar')
